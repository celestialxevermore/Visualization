# %%
import matplotlib.pyplot as plt 
import numpy as np

# %% [markdown]
# ### 6. Practices!!

# %%
fig = plt.figure(figsize=(7,7),facecolor='linen')

# %%
ax1 = fig.add_subplot(311)
ax2 = fig.add_subplot(312)
ax3 = fig.add_subplot(313)
fig

# %%
fig,axes = plt.subplots(3,1,figsize=(7,7))

# %%
fig3 = plt.figure(figsize=(7,7),facecolor='linen')
ax1 = plt.subplot2grid((3,3),(0,0),colspan=3,fig=fig3)
ax2 = plt.subplot2grid((3,3),(1,0),colspan=3,fig=fig3)
ax3 = plt.subplot2grid((3,3),(2,0),colspan=3,fig=fig3)

# %% [markdown]
# ### Practice 2

# %%
fig = plt.figure(figsize=(7,7),facecolor='linen')
ax1 = fig.add_subplot(221)
ax2 = fig.add_subplot(222)
ax3 = fig.add_subplot(223)
ax4 = fig.add_subplot(224)

# %%
fig,axis = plt.subplots(2,2,figsize=(7,7))

# %%
fig3 = plt.figure(figsize=(7,7),facecolor='linen')

ax1 = plt.subplot2grid((2,2),(0,0),colspan=1,fig=fig3)
ax2 = plt.subplot2grid((2,2),(0,1),colspan=1,fig=fig3)
ax3 = plt.subplot2grid((2,2),(1,0),colspan=1,fig=fig3)
ax4 = plt.subplot2grid((2,2),(1,1),colspan=1,fig=fig3)

# %% [markdown]
# ### Practice 3!!

# %%
fig_ = plt.figure(figsize=(7,7),facecolor='linen')

ax1 = fig_.add_subplot(121)
ax2 = fig_.add_subplot(222,projection='3d')
ax2 = fig_.add_subplot(224,projection='3d')

# %%
fig,axis = plt.subplots(1,2,figsize=(7,7))

# %%
fig = plt.figure(figsize=(7,7),facecolor='linen')
ax1 = plt.subplot2grid((2,2),(0,0),rowspan=2,fig=fig)
ax2 = plt.subplot2grid((2,2),(0,1),rowspan=1,fig=fig)
ax3 = plt.subplot2grid((2,2),(1,1),rowspan=1,fig=fig)

# %%
fig = plt.figure(figsize=(7,7),facecolor='linen')

ax1 = fig.add_subplot(321)
ax2 = fig.add_subplot(322)
ax3 = fig.add_subplot(5,4,9)
ax4 = fig.add_subplot(5,4,10)
ax5 = fig.add_subplot(5,4,11)
ax5 = fig.add_subplot(5,4,12)
ax5 = fig.add_subplot(5,4,13)
ax5 = fig.add_subplot(5,4,14)
ax5 = fig.add_subplot(5,4,15)
ax5 = fig.add_subplot(5,4,16)
ax5 = fig.add_subplot(5,4,17)
ax5 = fig.add_subplot(5,4,18)
ax5 = fig.add_subplot(5,4,19)
ax5 = fig.add_subplot(5,4,20)

# %%
fig,axis = plt.subplots(5,4)

# %%
fig = plt.figure(figsize=(7,7),facecolor='linen')
ax1 = plt.subplot2grid((5,4),(0,0),rowspan=2,colspan=2,fig=fig)
ax2 = plt.subplot2grid((5,4),(0,2),rowspan=2,colspan=2,fig=fig)

ax3 = plt.subplot2grid((5,4),(2,0),colspan=1,rowspan=1,fig=fig)
ax3 = plt.subplot2grid((5,4),(2,1),colspan=1,rowspan=1,fig=fig)
ax3 = plt.subplot2grid((5,4),(2,2),colspan=1,rowspan=1,fig=fig)
ax3 = plt.subplot2grid((5,4),(2,3),colspan=1,rowspan=1,fig=fig)

ax3 = plt.subplot2grid((5,4),(3,0),colspan=1,rowspan=1,fig=fig)
ax3 = plt.subplot2grid((5,4),(3,1),colspan=1,rowspan=1,fig=fig)
ax3 = plt.subplot2grid((5,4),(3,2),colspan=1,rowspan=1,fig=fig)
ax3 = plt.subplot2grid((5,4),(3,3),colspan=1,rowspan=1,fig=fig)

ax3 = plt.subplot2grid((5,4),(4,0),colspan=1,rowspan=1,fig=fig)
ax3 = plt.subplot2grid((5,4),(4,1),colspan=1,rowspan=1,fig=fig)
ax3 = plt.subplot2grid((5,4),(4,2),colspan=1,rowspan=1,fig=fig)
ax3 = plt.subplot2grid((5,4),(4,3),colspan=1,rowspan=1,fig=fig)

# %%
axes = np.empty(shape=(0,))
axes = np.append(axes,plt.subplot2grid((5,4),(0,0),rowspan=2,colspan=2))
axes = np.append(axes,plt.subplot2grid((5,4),(0,2),rowspan=2,colspan=2))

for r_idx in range(2,5):
    for c_idx in range(0,4):
        axes = np.append(axes,plt.subplot2grid((5,4),(r_idx,c_idx),rowspan=1,colspan=1))
