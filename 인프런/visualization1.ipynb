# %%
import matplotlib.pyplot as plt 
import numpy as np

# %%
#도화지 만들기..
fig = plt.figure()
fig = plt.figure(figsize=(7,7)) #presentation 에서는 좀 크게 만들면 좋음. 20 x 20 
fig = plt.figure(figsize=(7,7),facecolor='linen')

# %% [markdown]
# ### fig.ad_subplot

# %%
ax = fig.add_subplot() # 새끼 그림임. 
ax.plot([2,3,1])
ax.scatter([2,3,1],[2,3,4])

# %%
#ax1 = fig.add_subplot(3,1,1) # rows columns 몇 번째 그림
#ax2 = fig.add_subplot(3,1,2)
#ax3 = fig.add_subplot(3,1,3) 

''' 총 3 x 1 의 figure 안에, 순서대로 위부터 ax1, ax2, ax3가 나란히 들어가 있는 형태'''
# Out:
# ' 총 3 x 1 의 figure 안에, 순서대로 위부터 ax1, ax2, ax3가 나란히 들어가 있는 형태'

# %% [markdown]
# 2 x 2 인 경우

# %%
fig = plt.figure(facecolor='linen')
ax1 = fig.add_subplot(221)
ax2 = fig.add_subplot(222)
ax3 = fig.add_subplot(223)
ax4 = fig.add_subplot(224)

# %%
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_9240\89474557.py:1: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %% [markdown]
# 2 x 1 인 경우

# %%
fig_ = plt.figure(facecolor='linen')
ax1 = fig_.add_subplot(221)
ax2 = fig_.add_subplot(222)
ax3 = fig_.add_subplot(212)

# %% [markdown]
# Quiz.
#
# 231 232 234 235 133

# %%
quiz_fig = plt.figure(figsize=(2,3),facecolor='linen')
ax1 = quiz_fig.add_subplot(231,facecolor='r')
ax2 = quiz_fig.add_subplot(232,facecolor='g')
ax3 = quiz_fig.add_subplot(234,facecolor='b')
ax4 = quiz_fig.add_subplot(235)
ax5 = quiz_fig.add_subplot(133)
